# %% [markdown]
# <a href="https://colab.research.google.com/github/ddy2/YOLOv5s/blob/main/yolov5test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyqt5
# Out:
# ...
#      |████████████████████████████████| 8.3 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 59.9 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 338 kB 41.9 MB/s
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13442, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 13442 (delta 16), reused 7 (delta 3), pack-reused 13414
# Receiving objects: 100% (13442/13442), 12.10 MiB | 23.83 MiB/s, done.
# Resolving deltas: 100% (9371/9371), done.

# %%
# !pip install -U -r yolov5/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 5.9 MB/s
# ...
#      |████████████████████████████████| 60.5 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 33.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 47.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 38.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 35.8 MB/s
# ...
#      |████████████████████████████████| 930 kB 42.7 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: matplotlib
# ...

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
import torch
from IPython.display import Image

# %%
# %cd /content/
# Out:
# /content

# %%
# !unzip '/content/drive/MyDrive/train4.zip'
# Out:
# Archive:  /content/drive/MyDrive/train4.zip
#    creating: train/images/
#   inflating: train/images/11_00.png
#   inflating: train/images/11_01.png
#   inflating: train/images/11_26.png
#   inflating: train/images/12_00.png
#   inflating: train/images/12_19.png
#   inflating: train/images/16_00.png
#   inflating: train/images/16_01.png
#   inflating: train/images/16_12.png
#   inflating: train/images/16_13.png
#   inflating: train/images/24_00.png
#   inflating: train/images/24_19.png
#   inflating: train/images/24_20.png
#   inflating: train/images/27_00.png
#   inflating: train/images/27_14.png
#   inflating: train/images/28_00.png
#   inflating: train/images/28_01.png
#   inflating: train/images/28_13.png
#   inflating: train/images/28_14.png
#   inflating: train/images/28_15.png
#   inflating: train/images/28_36.png
#   inflating: train/images/33_00.png
#   inflating: train/images/33_10.png
#   inflating: train/images/34_00.png
#   inflating: train/images/34_16.png
# ...

# %%
# !ls
# Out:
# drive  sample_data  train  yolov5

# %%
# !cat /content/data.yaml
# Out:
# train: ../train/images
# val: ../train/images
#
# nc: 1
# names: ['colon']

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !ls
# Out:
# CONTRIBUTING.md  export.py   models	       setup.cfg       utils
# data		 hubconf.py  README.md	       train.py        val.py
# detect.py	 LICENSE     requirements.txt  tutorial.ipynb

# %%
# !python train.py --img 500 --batch 16 --epochs 300  --data /content/data.yaml --cfg ./models/yolov5s.yaml --weights ''
# Out:
# train: weights=, cfg=./models/yolov5s.yaml, data=/content/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=500, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-196-g614ef11 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !ls
# Out:
# CONTRIBUTING.md  hubconf.py   README.md		train.py
# data		 LICENSE      requirements.txt	tutorial.ipynb
# detect.py	 models       runs		utils
# export.py	 __pycache__  setup.cfg		val.py

# %%
# %cd runs
# Out:
# /content/yolov5/runs

# %%
# !ls
# Out:
# CONTRIBUTING.md  hubconf.py   README.md		train.py
# data		 LICENSE      requirements.txt	tutorial.ipynb
# detect.py	 models       runs		utils
# export.py	 __pycache__  setup.cfg		val.py

# %%
# %cd train
# Out:
# /content/yolov5/runs/train

# %%
# %cd exp
# Out:
# /content/yolov5/runs/train/exp

# %%
# !ls
# Out:
# confusion_matrix.png				   results.png
# events.out.tfevents.1652688472.876cdb74fad1.427.0  train_batch0.jpg
# F1_curve.png					   train_batch1.jpg
# hyp.yaml					   train_batch2.jpg
# labels_correlogram.jpg				   val_batch0_labels.jpg
# labels.jpg					   val_batch0_pred.jpg
# opt.yaml					   val_batch1_labels.jpg
# P_curve.png					   val_batch1_pred.jpg
# PR_curve.png					   val_batch2_labels.jpg
# R_curve.png					   val_batch2_pred.jpg
# results.csv					   weights

# %%
Image(filename='./results.png', width =900)

# %%
# %cd test

# %%
# !python /content/yolov5/detect.py --source /content/train/images/9_00.png --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.1
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/train/images/9_00.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-196-g614ef11 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/train/images/9_00.png: 640x512 Done. (0.029s)
# Speed: 0.5ms pre-process, 29.5ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
Image(filename='runs/detect/exp3/9_08.png', width =500)

# %%
# !unzip '/content/drive/MyDrive/3019png.zip'
# Out:
# Archive:  /content/drive/MyDrive/3019png.zip
# replace 3019png/1_00.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !python /content/yolov5/detect.py --source 3019png/ --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.4 --save-txt
# !python detect.py --weights runs/exp1/weights/best.pt --source inference/images/ --device 0 --save-txt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=3019png/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-196-g614ef11 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/3019 /content/yolov5/3019png/102_00.png: 640x448 Done. (0.027s)
# image 2/3019 /content/yolov5/3019png/102_01.png: 640x448 Done. (0.028s)
# image 3/3019 /content/yolov5/3019png/110_00.png: 640x256 Done. (0.022s)
# image 4/3019 /content/yolov5/3019png/110_01.png: 640x256 Done. (0.022s)
# ...

# %%
import shutil

# 压缩文件
shutil.make_archive('/content/drive/MyDrive/label2',format='zip',base_dir=r'/content/yolov5/runs/detect/exp8/labels')
# Out:
# '/content/drive/MyDrive/label2.zip'
